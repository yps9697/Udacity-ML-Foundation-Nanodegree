# %%
import os
path = os.getcwd()
print (path)
import pandas as p
fd = p.read_csv(path + '/stroopdata.csv')
fd
# Out:
# /Users/yps9697/Documents/Udacity MLFND Projects/Project 2
#              DATE      SP500  NASDAQ.AAL  NASDAQ.AAPL  NASDAQ.ADBE  \
# 0      1491226200  2363.6101     42.3300     143.6800     129.6300
# 1      1491226260  2364.1001     42.3600     143.7000     130.3200
# 2      1491226320  2362.6799     42.3100     143.6901     130.2250
# 3      1491226380  2364.3101     42.3700     143.6400     130.0729
# 4      1491226440  2364.8501     42.5378     143.6600     129.8800
# 5      1491226500  2365.6201     42.5399     143.7800     130.0700
# 6      1491226560  2365.2000     42.4700     143.8640     130.1800
# 7      1491226620  2365.2900     42.4700     143.8100     130.1400
# 8      1491226680  2364.3201     42.3900     143.8150     130.1000
# 9      1491226740  2364.6399     42.3300     143.8000     130.2100
# 10     1491226800  2364.5801     42.4000     143.8900     130.1400
# 11     1491226860  2364.4800     42.2900     143.9700     130.3700
# ...

# %%
fd['Subject'] = fd.index+1
fd
# Out:
#     Congruent  Incongruent  Subject
# 0      12.079       19.278        1
# 1      16.791       18.741        2
# 2       9.564       21.214        3
# 3       8.630       15.687        4
# 4      14.669       22.803        5
# 5      12.238       20.878        6
# 6      14.692       24.572        7
# 7       8.987       17.394        8
# 8       9.401       20.762        9
# 9      14.480       26.282       10
# 10     22.328       24.524       11
# 11     15.298       18.644       12
# 12     15.073       17.510       13
# 13     16.929       20.330       14
# 14     18.200       35.255       15
# 15     12.130       22.158       16
# 16     18.495       25.139       17
# 17     10.639       20.429       18
# 18     11.344       17.425       19
# 19     12.369       34.288       20
# 20     12.944       23.894       21
# 21     14.233       17.960       22
# 22     19.710       22.058       23
# 23     16.004       21.157       24

# %% [markdown]
# Question 1. What is our independent variable? What is our dependent variable?

# %% [markdown]
# INDEPENDENT VARIABLE - Word Condition's (Congruent or Incongruent).
# DEPENDENT VARIABLE  - Response Time in seconds.

# %% [markdown]
# Question 2. What is an appropriate set of hypotheses for this task? What kind of statistical test do you expect to perform? Justify your choices.

# %% [markdown]
# Null Hypothesis: ( μi - μc = 0 ) No significant difference in the population average response time in viewing the congruent(c) words vs viewing the incongruent(i) words.
#
# Alternative Hypothesis: ( μi - μc ≠ 0 ) Significant difference, positive or negative, in the population average response times.
#
# -The Dependent Samples t-Test is the appropriate statistical test as the same subjects are assigned two different conditions.
# -The different conditions are dependent because, in theory, by doing the first test you have some practice doing it and you might have an unfair advantage due to this learning effect in doing the similar type of test second.
# -In addition, we don't have any population parameters provided (so a z-test would not be appropriate here).

# %% [markdown]
# Question 3. Report some descriptive statistics regarding this dataset. Include at least one measure of central tendency and at least one measure of variability.

# %%
con = fd['Congruent']; inc = fd['Incongruent']

# %%
con_mean = con.mean(); round(con_mean,3)
# Out:
# 14.051

# %%
inc_mean = inc.mean(); round(inc_mean,3)
# Out:
# 22.016

# %%
con_sd = con.std(); round(con_sd,3)
# Out:
# 3.559

# %%
inc_sd = inc.std(); round(inc_sd,3)
# Out:
# 4.797

# %% [markdown]
# Question 4. Provide one or two visualizations that show the distribution of the sample data. Write one or two sentences noting what you observe about the plot or plots.

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

N = len(fd)
x = fd['Subject']
y = fd['Congruent']
colors = 'blue'
area = np.pi * 15 # 0 to 15 point radiuses

figure = plt.figure()
figure.suptitle('Congruent Words: ', fontsize=15, fontweight='regular')
ax = figure.add_subplot(111)
figure.subplots_adjust(top=0.84)
ax.set_title('Response Time Scatterplot')
ax.set_xlabel('Subjects')
ax.set_ylabel('Completion Time (seconds)')

plt.xticks(np.arange(min(x), max(x)+1, 1.0))
plt.yticks(np.arange(0, 40, 5))
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.ylim([0,35])
plt.xlim([0,24])
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

N = len(fd)
x = fd['Subject']
y = fd['Incongruent']
colors = 'red'
area = np.pi * 15 # 0 to 15 point radiuses

figure = plt.figure()
figure.suptitle('Incongruent Words: ', fontsize=15, fontweight='regular')
ax = figure.add_subplot(111)
figure.subplots_adjust(top=0.84)
ax.set_title('Response Time Scatterplot')
ax.set_xlabel('Subjects')
ax.set_ylabel('Completion Time (seconds)')

plt.xticks(np.arange(min(x), max(x)+1, 1.0))
plt.yticks(np.arange(0, 40, 5))
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.ylim([0,35])
plt.xlim([0,24])
plt.show()

# %% [markdown]
# Congruent words sample has a distribution which is between 8s and 22s and has a lower average completion time as compared to incongruent words scatterplot which shows that the distibtuion is between 15s to 26s. Therefore average completion time will be higher.

# %% [markdown]
# Question 5. Now, perform the statistical test and report your results. What is your confidence level and your critical statistic value? Do you reject the null hypothesis or fail to reject it? Come to a conclusion in terms of the experiment task. Did the results match up with your expectations?

# %% [markdown]
# Confidence Level = 90%
# t-critical value (2-sided test) -> from https://s3.amazonaws.com/udacity-hosted-downloads/t-table.jpg
# fd = n - 1 = 23(Degree of Freedom)
# tcrit = +- 1.711

# %%
#point estimate of μi - μc -> PE (in seconds)
PE = inc_mean - con_mean
round(PE,3)
# Out:
# 7.965

# %%
from math import *
#Sample Difference = D
fd['D'] = fd['Incongruent'] - fd['Congruent']

#Difference from the mean = DFM
#Squared Difference Mean = SQD
DFM = fd['D'] - fd['D'].mean()
fd['SQD'] = DFM*DFM

#Sum of squared differences = SSD
SSD = fd['SQD'].sum()

v = SSD/(n-1)

s = sqrt(v)
round(s,2)
# Out:
# 4.86

# %% [markdown]
# t-statistic > t-critical
# 8.0207 > 1.711
#
# Here are the results from two-tailed paired t-test.
# • Degrees of freedom (df-ic) = 23
# • Confidence Interval = 95%
# • Tail probability on both sides = 0.25
# • tcritical = +/- 1.711
# • Mean(μc-ic) = μc-μic = 14.051125 - 22.01591667 = -7.965
# • Standard Deviation (sc-ic) = 4.865
#
# We **reject** the Null Hypothesis which states that there is no significant differences between the population average completion time for the two different conditions (Congruent & Incongruent).
# We are able to calculate the average difference of every single person person who all took tests (the population) we expect there would be a significantly slower or significantly faster time in either the the incongruent or congruent condition.
